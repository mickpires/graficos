# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
# Filtro azul

azul = np.array([[1.5, 1.4, 1.3, 1.2, 1.1, 1. , 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1,0]]).T
azul_resultado = np.array([0,0,0,0.2,0.2,.5,1,2.2,4.4,8,14.5,28,37,51,65.8,84.8])

# filtro verde

verde = np.array([np.arange(1.3,0,-.09)])
verde  = verde.T
verde_resultado = np.array([0,0,0,0.2,.2,.4,.5,1,3,7.8,17,31,49,62.5,71])

# filtro vermelho

vermelho = np.array([[0.8 , 0.75, 0.7 , 0.65, 0.6 , 0.55, 0.5 , 0.45, 0.4, 0.35, 0.3,
       0.25, 0.2 , 0.15, 0.1 , 0.05,0]]).T
vermelho_resultado = np.array([0,0,0,0,.2,.2,.2,.4,.4,.4,.8,1.5,3.2,6,8.5,11,14])

# filtro amarelo
amarelo = np.array([np.arange(1.4,0.13,-.09)])
amarelo = amarelo.T
amarelo_resultado = np.array([0,0,.1,.3,.5,1,2,4,8,17.3,32,46.5,66.7,93.5,131])

# sem filtro

sem_filtro = np.array([np.arange(1.5,0.1,-.1)]).T
sem_filtro_resultado = np.array([0,.2,.4,.7,1,2,4,7.5,14.5,30,38.5,61,85,118])

# %%
model_azul = LinearRegression()
model_azul.fit(azul,azul_resultado)

model_verde = LinearRegression()
model_verde.fit(verde,verde_resultado)

model_vermelho = LinearRegression()
model_vermelho.fit(vermelho,vermelho_resultado)

model_amarelo = LinearRegression()
model_amarelo.fit(amarelo,amarelo_resultado)

model_sem_filtro = LinearRegression()
model_sem_filtro.fit(sem_filtro,sem_filtro_resultado)
# Out:
# LinearRegression()

# %% [markdown]
# modelo azul

# %%
# ax + b
print(f'a = {model_azul.coef_}')
print(f'b = {model_azul.intercept_}')
# Out:
# a = [-48.63823529]
# b = 55.07867647058822

# %%
plt.scatter(azul,azul_resultado)
plt.plot(azul,model_azul.predict(azul))
plt.xlabel('Diferença de Potencial (V)')
plt.ylabel("Corrente (nA)")
plt.title('Diferença de Potencial vs Corrente')
# Out:
# Text(0.5, 1.0, 'Diferença de Potencial vs Corrente')

# %%
print(f'coeficiente angular: {model_azul.coef_}')
print(f'Coeficiente linear: {model_azul.intercept_}')
# Out:
# coeficiente angular: [-48.63823529]
# Coeficiente linear: 55.07867647058822

# %%
plt.scatter(verde,verde_resultado)
plt.xlabel('Diferença de Potencial (V)')
plt.ylabel("Corrente (nA)")
plt.title('Diferença de Potencial vs Corrente')
# Out:
# Text(0.5, 1.0, 'Diferença de Potencial vs Corrente')

# %%
print(f'coeficiente angular: {model_verde.coef_}')
print(f'Coeficiente linear: {model_verde.intercept_}')
# Out:
# coeficiente angular: [-51.90079365]
# Coeficiente linear: 51.01353174603169

# %%
plt.scatter(vermelho,vermelho_resultado)
plt.xlabel('Diferença de Potencial (V)')
plt.ylabel("Corrente (nA)")
plt.title('Diferença de Potencial vs Corrente')
# Out:
# Text(0.5, 1.0, 'Diferença de Potencial vs Corrente')

# %%
print(f'coeficiente angular: {model_vermelho.coef_}')
print(f'Coeficiente linear: {model_vermelho.intercept_}')
# Out:
# coeficiente angular: [-14.07352941]
# Coeficiente linear: 8.382352941176471

# %%
plt.scatter(amarelo,amarelo_resultado)
plt.xlabel('Diferença de Potencial (V)')
plt.ylabel("Corrente (nA)")
plt.title('Diferença de Potencial vs Corrente')
# Out:
# Text(0.5, 1.0, 'Diferença de Potencial vs Corrente')

# %%
print(f'coeficiente angular: {model_amarelo.coef_}')
print(f'Coeficiente linear: {model_amarelo.intercept_}')
# Out:
# coeficiente angular: [-84.48015873]
# Coeficiente linear: 91.90972222222211

# %%
plt.scatter(sem_filtro,sem_filtro_resultado)
plt.xlabel('Diferença de Potencial (V)')
plt.ylabel("Corrente (nA)")
plt.title('Diferença de Potencial vs Corrente')
# Out:
# Text(0.5, 1.0, 'Diferença de Potencial vs Corrente')

# %%
print(f'coeficiente angular: {model_sem_filtro.coef_}')
print(f'Coeficiente linear: {model_sem_filtro.intercept_}')
# Out:
# coeficiente angular: [-76.10549451]
# Coeficiente linear: 90.60395604395595

# %%
total = np.append(azul,verde,vermelho,amarelo,sem_filtro)
total_resultado = np.append(azul_resultado,verde_resultado,vermelho_resultado,amarelo_resultado,sem_filtro_resultado)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 total = np.append(azul,verde,vermelho,amarelo,sem_filtro)
#       2 total_resultado = np.append(azul_resultado,verde_resultado,vermelho_resultado,amarelo_resultado,sem_filtro_resultado)
#
# File <__array_function__ internals>:179, in append(*args, **kwargs)
#
# TypeError: _append_dispatcher() takes from 2 to 3 positional arguments but 5 were given

# %%
total = azul.copy()
for array in [verde,vermelho,amarelo,sem_filtro]:
    total = np.append(total,array)

# %%
total_resultado = azul_resultado.copy()

for array in [verde_resultado,vermelho_resultado,amarelo_resultado,sem_filtro_resultado]:
    total_resultado = np.append(total_resultado,array)

# %%
plt.scatter(total,total_resultado)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 2
#       1 total_model = LinearRegression()
# ----> 2 total_model.fit(total,total_resultado)
#
# File c:\Users\rocha\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
#     661     sample_weight=sample_weight,
#     662 )
#
# ...
